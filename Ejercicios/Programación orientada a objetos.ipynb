# %%
class Perro:
    pass

# %%
class Perro:
    def __init__(self,nombre_,edad_):
        self.nombre = nombre_
        self.edad = edad_

# %%
fir = Perro("Firulais",5)

# %%
fir.edad
# Out:
# 5

# %%
fir.nombre
# Out:
# 'Firulais'
